# %% [markdown]
# # Google COVID-19 Community Mobility Reports

# %% [markdown]
# Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import data from [Google Site](https://www.google.com/covid19/mobility/)

# %%
df = pd.read_csv("https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Check the data

# %%
df.head()
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
# 3                  AE  United Arab Emirates          NaN          NaN
# 4                  AE  United Arab Emirates          NaN          NaN
#
#   metro_area iso_3166_2_code  census_fips_code                     place_id  \
# 0        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 1        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 2        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 3        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
# 4        NaN             NaN               NaN  ChIJvRKrsd9IXj4RpwoIwFYv0zM
#
#          date  retail_and_recreation_percent_change_from_baseline  \
# 0  2020-02-15                                                0.0
# 1  2020-02-16                                                1.0
# 2  2020-02-17                                               -1.0
# 3  2020-02-18                                               -2.0
# 4  2020-02-19                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# 1                                                4.0
# 2                                                1.0
# 3                                                1.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 4.0
# 2                                 5.0
# 3                                 5.0
# 4                                 4.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            0.0
# 1                                            1.0
# 2                                            1.0
# 3                                            0.0
# 4                                           -1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      2.0
# 2                                      2.0
# 3                                      2.0
# 4                                      2.0
#
#    residential_percent_change_from_baseline
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0

# %% [markdown]
# Filter the data

# %%
laos = df[df["country_region_code"] == "LA"]

# %% [markdown]
# Check the data

# %%
laos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 763 entries, 4670681 to 4671443
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   country_region_code                                 763 non-null    object
#  1   country_region                                      763 non-null    object
#  2   sub_region_1                                        0 non-null      object
#  3   sub_region_2                                        0 non-null      object
#  4   metro_area                                          0 non-null      object
#  5   iso_3166_2_code                                     0 non-null      object
#  6   census_fips_code                                    0 non-null      float64
#  7   place_id                                            763 non-null    object
#  8   date                                                763 non-null    object
#  9   retail_and_recreation_percent_change_from_baseline  763 non-null    float64
#  10  grocery_and_pharmacy_percent_change_from_baseline   763 non-null    float64
#  11  parks_percent_change_from_baseline                  763 non-null    float64
#  12  transit_stations_percent_change_from_baseline       763 non-null    float64
#  13  workplaces_percent_change_from_baseline             763 non-null    float64
#  14  residential_percent_change_from_baseline            763 non-null    float64
# dtypes: float64(7), object(8)
# memory usage: 95.4+ KB

# %%
laos.tail()
# Out:
#         country_region_code country_region sub_region_1 sub_region_2  \
# 4671439                  LA           Laos          NaN          NaN
# 4671440                  LA           Laos          NaN          NaN
# 4671441                  LA           Laos          NaN          NaN
# 4671442                  LA           Laos          NaN          NaN
# 4671443                  LA           Laos          NaN          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 4671439        NaN             NaN               NaN
# 4671440        NaN             NaN               NaN
# 4671441        NaN             NaN               NaN
# 4671442        NaN             NaN               NaN
# 4671443        NaN             NaN               NaN
#
#                             place_id        date  \
# 4671439  ChIJiUWCsFeQFDERgc2ZH0iSxQ4  2022-03-14
# 4671440  ChIJiUWCsFeQFDERgc2ZH0iSxQ4  2022-03-15
# 4671441  ChIJiUWCsFeQFDERgc2ZH0iSxQ4  2022-03-16
# 4671442  ChIJiUWCsFeQFDERgc2ZH0iSxQ4  2022-03-17
# 4671443  ChIJiUWCsFeQFDERgc2ZH0iSxQ4  2022-03-18
#
#          retail_and_recreation_percent_change_from_baseline  \
# 4671439                                                5.0
# 4671440                                                3.0
# 4671441                                               -1.0
# 4671442                                                3.0
# 4671443                                                1.0
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 4671439                                               20.0
# 4671440                                               18.0
# 4671441                                               13.0
# 4671442                                               16.0
# 4671443                                               10.0
#
#          parks_percent_change_from_baseline  \
# 4671439                                31.0
# 4671440                                28.0
# 4671441                                31.0
# 4671442                                34.0
# 4671443                                30.0
#
#          transit_stations_percent_change_from_baseline  \
# 4671439                                          -20.0
# 4671440                                          -20.0
# 4671441                                          -20.0
# 4671442                                          -24.0
# 4671443                                          -25.0
#
#          workplaces_percent_change_from_baseline  \
# 4671439                                     10.0
# 4671440                                      8.0
# 4671441                                      8.0
# 4671442                                     10.0
# 4671443                                     17.0
#
#          residential_percent_change_from_baseline
# 4671439                                      15.0
# 4671440                                      16.0
# 4671441                                      16.0
# 4671442                                      16.0
# 4671443                                      18.0

# %% [markdown]
# Export the filtered data ('laos') to CSV file

# %%
laos.to_csv("laos_Google_community_mobility_reports.csv", index = False)
